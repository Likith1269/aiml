# %%
word = input("Enter a word: ")

while word != "Bon":
    word = input("Enter a word: ")
    print("Voyage")
    break
# Out:
# Enter a word:  voyage
# Enter a word:  bon
# Voyage

# %%
word = input("Enter a word: ")

while word != "Bon":
    word = input("Enter a word: ")
    print("Voyage")
    break
# Out:
# Enter a word:  e
# Enter a word:  kj
# Voyage

# %%
my_tuple = (10, 20, 30, 20, 40)
index_of_20 = my_tuple.index(20)
print("Index of 20:", index_of_20)
# Out:
# Index of 20: 1

# %%
my_tuple = (10, 10, 20, 30, 10, 10, 10)
count_10 = my_tuple.count(10)
print("Count of 10:", count_10)
# Out:
# Count of 10: 5

# %%
t = (10, 20, 30, 20, 40, 20, 50)
target = 20
indexes = []
for index, element in enumerate(t):
    if element == target:
        indexes.append(index)
print(indexes)
# Out:
# [1, 3, 5]

# %%
s = {1,2,3}
s.clear()
print(s)
# Out:
# set()

# %%
s = {1,2,3}
s.remove(3)
print(s)
# Out:
# {1, 2}

# %%
numbers = [1, 2, 3, 2, 4, 1, 5]
n = list(set(numbers))
print(n)
print(f" removed duplicate items" )
# Out:
# [1, 2, 3, 4, 5]
#  removed duplicate items
